# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Listas

# %% [markdown]
# Criei uma lista chamada `filmes` com o nome dos 10 primeiros filmes mais bem avaliados no site no [IMDB](https://www.imdb.com/chart/top/). Imprima o resultado.

# %%
filmes = list(('Um Sonho de Liberdade', 
               'O Poderoso Chefão', 
               'Batman: O Cavaleiro das Trevas', 
               'O Poderoso Chefão II',
               '12 Homens e uma Sentença',
               'A Lista de Schindler',
               'O Senhor dos Anéis: O Retorno do Rei',
               'Pulp Fiction: Tempo de Violência',
               'O Senhor dos Anéis: A Sociedade do Anel',
               'Três Homens em Conflito'))

print(filmes)
# Out:
# ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction: Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']
# <class 'list'>

# %% [markdown]
# Simule a movimentação do *ranking*. Utilize os métodos `insert` e `pop` para trocar a posição do primeiro e do segundo filme da lista. Imprima o resultado.

# %%
ranking = list(('Um Sonho de Liberdade', 
                'O Poderoso Chefão', 
                'Batman: O Cavaleiro das Trevas'))

ranking.insert(0, 'O Poderoso Chefão')
ranking.pop(2)
print(ranking)
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman: O Cavaleiro das Trevas']

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Conjuntos

# %% [markdown]
# Aconteceu um erro no seu *ranking*. Simule a duplicação dos três últimos filmes da lista. Imprima o resultado.

# %%
ranking = list(('Um Sonho de Liberdade', 
                'Um Sonho de Liberdade',
                'O Poderoso Chefão', 
                'O Poderoso Chefão',
                'Batman: O Cavaleiro das Trevas',
                'Batman: O Cavaleiro das Trevas'))
# Out:
# ['Um Sonho de Liberdade', 'Um Sonho de Liberdade', 'O Poderoso Chefão', 'O Poderoso Chefão', 'Batman: O Cavaleiro das Trevas', 'Batman: O Cavaleiro das Trevas']

# %% [markdown]
# Utiliza a conversão `set` e `list` para remover os valores duplicados. Imprima o resultado.

# %%
print(list(set(ranking)))
# Out:
# ['Um Sonho de Liberdade', 'Batman: O Cavaleiro das Trevas', 'O Poderoso Chefão']

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Dicionários

# %% [markdown]
# Repita os exercícios da parte 1 (listas). Os elementos da lista `filmes` devem ser dicionários no seguinte formato: `{'nome': <nome-do-filme>, 'ano': <ano do filme>}, 'sinopse': <sinopse do filme>}`.

# %%
filmes = dict(filme1 = dict(nome = 'Um Sonho de Liberdade', 
                            ano = 1994,
                            sinopse = 'Dois homens presos ...'),
              filme2 = dict(nome = 'O Poderoso Chefão', 
                            ano = 1972,
                            sinopse = 'O patriarca idoso ...'),
              filme3 = dict(nome = 'Batman: O Cavaleiro das Trevas', 
                            ano = 2008,
                            sinopse = 'Quando a ameaça conhecida ...'),
              filme4 = dict(nome = 'O Poderoso Chefão II', 
                            ano = 1974,
                            sinopse = 'Em 1950, Michael Corleone ...'),
              filme5 = dict(nome = '12 Homens e uma Sentença', 
                            ano = 1957,
                            sinopse = 'Um jurado que se aposenta ...'),
              filme6 = dict(nome = 'A Lista de Schindlera', 
                            ano = 1993,
                            sinopse = 'Depois de testemunhar a ...'),
              filme7 = dict(nome = 'O Senhor dos Anéis: O Retorno do Rei', 
                            ano = 2003,
                            sinopse = 'Gandalf e Aragorn lideram ...'),
              filme8 = dict(nome = 'Pulp Fiction: Tempo de Violência', 
                            ano = 1994,
                            sinopse = 'As vidas de dois assassinos ...'),
              filme9 = dict(nome = 'O Senhor dos Anéis: A Sociedade do Anel', 
                            ano = 2001,
                            sinopse = 'Um manso hobbit do Condado ...'),
              filme10 = dict(nome = 'Três Homens em Conflito', 
                            ano = 1966,
                            sinopse = 'Um impostor se junta ...')
              )
print(filmes)
# Out:
# {'filme1': {'nome': 'Um Sonho de Liberdade', 'ano': 1994, 'sinopse': 'Dois homens presos ...'}, 'filme2': {'nome': 'O Poderoso Chefão', 'ano': 1972, 'sinopse': 'O patriarca idoso ...'}, 'filme3': {'nome': 'Batman: O Cavaleiro das Trevas', 'ano': 2008, 'sinopse': 'Quando a ameaça conhecida ...'}, 'filme4': {'nome': 'O Poderoso Chefão II', 'ano': 1974, 'sinopse': 'Em 1950, Michael Corleone ...'}, 'filme5': {'nome': '12 Homens e uma Sentença', 'ano': 1957, 'sinopse': 'Um jurado que se aposenta ...'}, 'filme6': {'nome': 'A Lista de Schindlera', 'ano': 1993, 'sinopse': 'Depois de testemunhar a ...'}, 'filme7': {'nome': 'O Senhor dos Anéis: O Retorno do Rei', 'ano': 2003, 'sinopse': 'Gandalf e Aragorn lideram ...'}, 'filme8': {'nome': 'Pulp Fiction: Tempo de Violência', 'ano': 1994, 'sinopse': 'As vidas de dois assassinos ...'}, 'filme9': {'nome': 'O Senhor dos Anéis: A Sociedade do Anel', 'ano': 2001, 'sinopse': 'Um manso hobbit do Condado ...'}, 'filme10': {'nome': 'Três Homens em Confli
# ...
