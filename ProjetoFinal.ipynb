# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Python: Projeto Final**
# Aluna: [Izabelle Aller](https://www.linkedin.com/in/izabellealler/)<br>
# Professor: [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Resumo**
# Projeto final do curso Python para Análise de Dados da Escola Britânica de Artes Criativas & Tecnologia (EBAC). Foi proposto o estudo de informações cedidas por uma instituição que concede empréstimos. O intuito é tentar entender o que faz um cliente virar inadimplente, já que para o sucesso destas institiuções é essencial mitigar a inadimplência.
#
# ---

# %% [markdown]
# # **Sumário**
#
# <ol type="1">
#   <li>Exploração de dados</li>
#   <li>Transformação e limpeza de dados</li>
#   <li>Visualização de dados</li>
#   <li>Conclusões</li>
# </ol>
#
# ---

# %% [markdown]
# # 1\. Exploração de Dados

# %% [markdown]
# Os dados estão no formato CSV e contém informações sobre clientes de uma instituição financeira. Em especial, estamos interessados em explicar a segunda coluna, chamada de **default**, que indica se um cliente é adimplente(`default = 0`), ou inadimplente (`default = 1`), ou seja, queremos entender o porque um cliente deixa de honrar com suas dívidas baseado no comportamento de outros atributos, como salário, escolaridade e movimentação financeira. Uma descrição completa dos atributos está abaixo.

# %% [markdown]
# | Coluna  | Descrição |
# | ------- | --------- |
# | id      | Número da conta |
# | default | Indica se o cliente é adimplente (0) ou inadimplente (1) |
# | idade   | --- |
# | sexo    | --- |
# | depedentes | --- |
# | escolaridade | --- |
# | estado_civil | --- |
# | salario_anual | Faixa do salario mensal multiplicado por 12 |
# | tipo_cartao | Categoria do cartao: blue, silver, gold e platinium |
# | meses_de_relacionamento | Quantidade de meses desde a abertura da conta |
# | qtd_produtos | Quantidade de produtos contratados |
# | iteracoes_12m | Quantidade de iteracoes com o cliente no último ano |
# | meses_inatico_12m | Quantidade de meses que o cliente ficou inativo no último ano |
# | limite_credito | Valor do limite do cartão de crédito |
# | valor_transacoes_12m | Soma total do valor das transações no cartão de crédito no último ano |
# | qtd_transacoes_12m | Quantidade total de transações no cartão de crédito no último ano |

# %% [markdown]
# Para processar os dados, vamos utilizar o pacote `pandas`. Já para a visualização os dados, vamos utilizar o pacote `seaborn` e o `matplotlib`.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Vamos começar lendos os dados num dataframe `pandas`.

# %%
df = pd.read_csv('/content/credito.csv', na_values='na')

# %%
df.head(n=5)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
# Com o dados em mãos, vamos conhecer um pouco melhor a estrutura do nosso conjunto de dados.

# %% [markdown]
# ### **1.1. Estrutura**

# %%
df.shape
# Out:
# (10127, 16)

# %%
df[df['default'] == 0].shape
# Out:
# (8500, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1627, 16)

# %%
qtd_total, _ = df.shape
qtd_adimplentes, _ = df[df['default'] == 0].shape
qtd_inadimplentes, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão clientes adimplentes é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
# Out:
# A proporcão clientes adimplentes é de 83.93%
# A proporcão clientes inadimplentes é de 16.07%

# %% [markdown]
# ### **1.2. Schema**

# %%
df.head(n=5)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
#  - Colunas e seus respectivos tipos de dados.

# %%
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %% [markdown]
#  - Atributos **categóricos**.

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                       count unique             top  freq
# sexo                  10127      2               F  5358
# escolaridade           8608      5        mestrado  3128
# estado_civil           9378      3          casado  4687
# salario_anual          9015      5  menos que $40K  3561
# tipo_cartao           10127      4            blue  9436
# limite_credito        10127   9272        1.438,21    11
# valor_transacoes_12m  10127  10035        3.851,51     3

# %% [markdown]
#  - Atributos **numéricos**.

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count       mean        std   min   25%   50%  \
# default                  10127.0   0.160660   0.367235   0.0   0.0   0.0
# idade                    10127.0  46.325960   8.016814  26.0  41.0  46.0
# dependentes              10127.0   2.346203   1.298908   0.0   1.0   2.0
# meses_de_relacionamento  10127.0  35.928409   7.986416  13.0  31.0  36.0
# qtd_produtos             10127.0   3.812580   1.554408   1.0   3.0   4.0
# iteracoes_12m            10127.0   2.455317   1.106225   0.0   2.0   2.0
# meses_inativo_12m        10127.0   2.341167   1.010622   0.0   2.0   2.0
# qtd_transacoes_12m       10127.0  64.858695  23.472570  10.0  45.0  67.0
#
#                           75%    max
# default                   0.0    1.0
# idade                    52.0   73.0
# dependentes               3.0    5.0
# meses_de_relacionamento  40.0   56.0
# qtd_produtos              5.0    6.0
# iteracoes_12m             3.0    6.0
# meses_inativo_12m         3.0    6.0
# ...

# %% [markdown]
# ### **1.3. Dados faltantes**

# %% [markdown]
# Dados faltantes podem ser:
#
#  - Vazios (`""`);
#  - Nulos (`None`);
#  - Não disponíveis ou aplicaveis (`na`, `NA`, etc.);
#  - Não numérico (`nan`, `NaN`, `NAN`, etc).

# %%
df.head()
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
# Podemos verificar quais colunas possuem dados faltantes.

# %%
df.isna().any()
# Out:
# id                         False
# default                    False
# idade                      False
# sexo                       False
# dependentes                False
# escolaridade                True
# estado_civil                True
# salario_anual               True
# tipo_cartao                False
# meses_de_relacionamento    False
# qtd_produtos               False
# iteracoes_12m              False
# meses_inativo_12m          False
# limite_credito             False
# valor_transacoes_12m       False
# qtd_transacoes_12m         False
# dtype: bool

# %% [markdown]
#  - A função abaixo levanta algumas estatisticas sobre as colunas dos dados faltantes.

# %%
def stats_dados_faltantes(df: pd.DataFrame) -> None:

  stats_dados_faltantes = list()
  for col in df.columns:
    if df[col].isna().any():
      qtd, _ = df[df[col].isna()].shape
      total, _ = df.shape
      dict_dados_faltantes = {col: {'quantidade': qtd, "porcentagem": round(100 * qtd/total, 2)}}
      stats_dados_faltantes.append(dict_dados_faltantes)

  for stat in stats_dados_faltantes:
    print(stat)

# %%
stats_dados_faltantes(df=df)
# Out:
# {'escolaridade': {'quantidade': 1519, 'porcentagem': 15.0}}
# {'estado_civil': {'quantidade': 749, 'porcentagem': 7.4}}
# {'salario_anual': {'quantidade': 1112, 'porcentagem': 10.98}}

# %%
stats_dados_faltantes(df=df[df['default'] == 0])
# Out:
# {'escolaridade': {'quantidade': 1263, 'porcentagem': 14.86}}
# {'estado_civil': {'quantidade': 620, 'porcentagem': 7.29}}
# {'salario_anual': {'quantidade': 925, 'porcentagem': 10.88}}

# %%
stats_dados_faltantes(df=df[df['default'] == 1])
# Out:
# {'escolaridade': {'quantidade': 256, 'porcentagem': 15.73}}
# {'estado_civil': {'quantidade': 129, 'porcentagem': 7.93}}
# {'salario_anual': {'quantidade': 187, 'porcentagem': 11.49}}

# %% [markdown]
# # 2\. Transformação e limpeza de dados

# %% [markdown]
# Agora que conhecemos melhor a natureza do nosso conjunto de dados, vamos conduzir uma atividade conhecida como *data wrangling* que consiste na transformação e limpeza dos dados do conjunto para que possam ser melhor analisados. Em especial, vamos remover:
#
#  - Corrigir o *schema* das nossas colunas;
#  - Remover os dados faltantes.

# %% [markdown]
# ### **2.1. Correção de schema**

# %% [markdown]
# Na etapa de exploração, notamos que as colunas **limite_credito** e **valor_transacoes_12m** estavam sendo interpretadas como colunas categóricas (`dtype = object`).

# %%
df[['limite_credito', 'valor_transacoes_12m']].dtypes
# Out:
# limite_credito          object
# valor_transacoes_12m    object
# dtype: object

# %%
df[['limite_credito', 'valor_transacoes_12m']].head(n=5)
# Out:
#   limite_credito valor_transacoes_12m
# 0      12.691,51             1.144,90
# 1       8.256,96             1.291,45
# 2       3.418,56             1.887,72
# 3       3.313,03             1.171,56
# 4       4.716,22               816,08

# %% [markdown]
# Vamos criar uma função `lambda` para limpar os dados.

# %%
df['valor_transacoes_12m'] = df['valor_transacoes_12m'].apply(lambda valor: float(valor.replace(".", "").replace(",", ".")))
df['limite_credito'] = df['limite_credito'].apply(lambda valor: float(valor.replace(".", "").replace(",", ".")))

# %% [markdown]
# Vamos descrever novamente o *schema*:

# %%
df.dtypes
# Out:
# id                           int64
# default                      int64
# idade                        int64
# sexo                        object
# dependentes                  int64
# escolaridade                object
# estado_civil                object
# salario_anual               object
# tipo_cartao                 object
# meses_de_relacionamento      int64
# qtd_produtos                 int64
# iteracoes_12m                int64
# meses_inativo_12m            int64
# limite_credito             float64
# valor_transacoes_12m       float64
# qtd_transacoes_12m           int64
# dtype: object

# %% [markdown]
#  - Atributos **categóricos**.

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                count unique             top  freq
# sexo           10127      2               F  5358
# escolaridade    8608      5        mestrado  3128
# estado_civil    9378      3          casado  4687
# salario_anual   9015      5  menos que $40K  3561
# tipo_cartao    10127      4            blue  9436

# %% [markdown]
#  - Atributos **numéricos**.

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count         mean          std      min       25%  \
# default                  10127.0     0.160660     0.367235     0.00     0.000
# idade                    10127.0    46.325960     8.016814    26.00    41.000
# dependentes              10127.0     2.346203     1.298908     0.00     1.000
# meses_de_relacionamento  10127.0    35.928409     7.986416    13.00    31.000
# qtd_produtos             10127.0     3.812580     1.554408     1.00     3.000
# iteracoes_12m            10127.0     2.455317     1.106225     0.00     2.000
# meses_inativo_12m        10127.0     2.341167     1.010622     0.00     2.000
# limite_credito           10127.0  8632.440165  9088.788041  1438.00  2555.355
# valor_transacoes_12m     10127.0  4404.583047  3397.128078   510.16  2155.825
# qtd_transacoes_12m       10127.0    64.858695    23.472570    10.00    45.000
#
#                              50%        75%       max
# default                     0.00      0.000      1.00
# ...

# %% [markdown]
# ### **2.2. Remoção de dados faltantes**

# %% [markdown]
# Como o pandas está ciente do que é um dados faltante, a remoção das linhas problemáticas é trivial.

# %%
df.dropna(inplace=True)

# %% [markdown]
# Vamos analisar a estrutura dos dados novamente.

# %%
df.shape
# Out:
# (7081, 16)

# %%
df[df['default'] == 0].shape
# Out:
# (5968, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1113, 16)

# %%
qtd_total_novo, _ = df.shape
qtd_adimplentes_novo, _ = df[df['default'] == 0].shape
qtd_inadimplentes_novo, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão adimplentes ativos é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes adimplentes é de {round(100 * qtd_adimplentes_novo / qtd_total_novo, 2)}%")
print("")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes inadimplentes é de {round(100 * qtd_inadimplentes_novo / qtd_total_novo, 2)}%")
# Out:
# A proporcão adimplentes ativos é de 83.93%
# A nova proporcão de clientes adimplentes é de 84.28%
#
# A proporcão clientes inadimplentes é de 16.07%
# A nova proporcão de clientes inadimplentes é de 15.72%

# %% [markdown]
# # 3\. Visualização de dados

# %% [markdown]
# Os dados estão prontos, vamos criar diversas visualizações para correlacionar variáveis explicativas com a variável resposta para buscar entender qual fator leva um cliente a inadimplencia. E para isso, vamos sempre comparar a base com todos os clientes com a base de adimplentes e inadimplentes.

# %% [markdown]
# Começamos então importando os pacotes de visualização e separando os clientes adimplentes e inadimplentes

# %%
sns.set_style("whitegrid")

# %%
df_adimplente = df[df['default'] == 0]

# %%
df_inadimplente = df[df['default'] == 1]

# %% [markdown]
# ### **3.1. Visualizações numéricas**

# %% [markdown]
# Nesta seção, vamos visualizar a relação entre a variável resposta **default** com os atributos numéricos.

# %%
df.drop(['id', 'default'], axis=1).select_dtypes('number').head(n=5)
# Out:
#    idade  dependentes  meses_de_relacionamento  qtd_produtos  iteracoes_12m  \
# 0     45            3                       39             5              3
# 1     49            5                       44             6              2
# 2     51            3                       36             4              0
# 4     40            3                       21             5              0
# 5     44            2                       36             3              2
#
#    meses_inativo_12m  limite_credito  valor_transacoes_12m  qtd_transacoes_12m
# 0                  1        12691.51               1144.90                  42
# 1                  1         8256.96               1291.45                  33
# 2                  1         3418.56               1887.72                  20
# 4                  1         4716.22                816.08                  28
# 5                  1         4010.69               1088.07                  24

# %% [markdown]
# Correlação entre os atributos numéricos:

# %%
f = sns.heatmap(df.drop(['id', 'default'], axis=1).select_dtypes('number').corr(), cmap='RdBu', square='True')
_ = f.set(title='Matriz de correlação')

# %% [markdown]
# Primeiramente, vamos analisar os atributos numéricos **idade** e **meses_de_renacionamento**.

# %% [markdown]
# *   Idade

# %%
coluna = 'idade'
titulos = ['Idade', 'Idade dos Adimplentes', 'Idade dos Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo], palette='RdBu')
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# *  Meses de Relacionamento

# %%
coluna = 'meses_de_relacionamento'
titulos = ['Meses de Relacionamento', 'Meses de Relacionamento dos Adimplentes', 'Meses de Relacionamento dos Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo], palette='RdBu')
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
# * Idade x Meses de Relacionamento

# %%
f = sns.relplot(x='idade', y='meses_de_relacionamento', data=df, hue='default', palette='RdBu')
_ = f.set(
    title='Relação entre Idade e Meses de Relacionamento', 
    xlabel='Idade', 
    ylabel='Meses de Relacionamento'
  )

# %% [markdown]
# Vamos também analisar os atributos numéricos **qtd_transacoes_12m** e **valor_transacoes_12m**.

# %% [markdown]
#  - Quantidade de Transações nos Últimos 12 Meses

# %%
coluna = 'qtd_transacoes_12m'
titulos = ['Qtd. de Transações no Último Ano', 'Qtd. de Transações no Último Ano de Adimplentes', 'Qtd. de Transações no Último Ano de Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo], palette='RdBu')
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
#  - Valor das Transações nos Últimos 12 Meses

# %%
coluna = 'valor_transacoes_12m'
titulos = ['Valor das Transações no Último Ano', 'Valor das Transações no Último Ano de Adimplentes', 'Valor das Transações no Último Ano de Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo], palette='RdBu')
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

figura.show()

# %% [markdown]
#  - Valor de Transações nos Últimos 12 Meses x Quantidade de Transações nos Últimos 12 Meses

# %%
f = sns.relplot(x='valor_transacoes_12m', y='qtd_transacoes_12m', data=df, hue='default', palette='RdBu')
_ = f.set(
    title='Relação entre Valor e Quantidade de Transações no Último Ano', 
    xlabel='Valor das Transações no Último Ano', 
    ylabel='Quantidade das Transações no Último Ano'
  )

# %% [markdown]
# # 4\. Conclusões

# %% [markdown]
# *   Clientes com altos valores de transações no último ano não apresentam inadimplência.
# *   Conforme os valores de transações no último ano diminuem define-se dois grupos de inadimplentes, portanto, é preciso avaliar medidas para que tais grupos diminuam.
# *   A idade e os meses de relacionamento dos clientes não indicam nenhum grupo, onde há a necessidade de medidas para mitigar a inadimplência.
